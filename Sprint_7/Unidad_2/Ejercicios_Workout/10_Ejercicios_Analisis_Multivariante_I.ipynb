# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Para ejercitarte y afianzar lo aprendido sobre el análisis bivariante, completa los siguientes ejercicios. Recuerda que necesitarás datos que están en el directorio data que acompaña al notebook (búscalo en el repositorio de ejercicios)
#
# La solución a los mismos se subirá a lo largo del sprint.

# %% [markdown]
# ### Ejercicio 0
#
#
# Importa los paquetes y módulos que necesites a lo largo del notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from bootcampviztools import plot_categorical_numerical_relationship, plot_combined_graphs, pinta_distribucion_categoricas, plot_grouped_boxplots, grafico_dispersion_con_correlacion, plot_categorical_relationship_fin

# %% [markdown]
# ### Ejercicio 1

# %% [markdown]
# Carga el dataset de admisiones que conoces de la unidad anterior y que se encuentra en la ruta "./data/admission_data.csv", deshazte de las columnas innecesarias

# %%
df = pd.read_csv("/Users/alvarosanchez/ONLINE_DS_THEBRIDGE_ALVAROSMMS-1/ONLINE_DS_THEBRIDGE_ALVAROSMMS/Sprint_7/Unidad_2/Ejercicios_Workout/data/admission_data.csv")

df.head()
# Out:
#    Unnamed: 0  Year                    Major Gender Admission
# 0           0  1973       School of Medicine      F  Rejected
# 1           1  1973  Department of Economics      M  Accepted
# 2           2  1973                    Other      F  Accepted
# 3           3  1973                    Other      M  Accepted
# 4           4  1973                    Other      M  Rejected

# %%
df = df.drop(columns=["Unnamed: 0"])

# %% [markdown]
# ### Ejercicio 2

# %% [markdown]
# Haz el análisis bivariante de "Admission" y "Major" (emplea las funciones del workout importándolas del módulo `bootcampviztools`, o utiliza las visualizaciones del notebook en el repositorio) y contesta a las siguientes preguntas:
# * ¿Cuál es el departamento con el mayor porcentaje de admsiones?¿Y el de menor?
# * ¿Existe alguna diferencia destacada entre los departamentos?

# %%
pinta_distribucion_categoricas(df,["Admission","Major"], relativa= True, mostrar_valores= True)

# %%
plot_categorical_relationship_fin(df, "Major","Admission", show_values= True)

# %%
plot_categorical_relationship_fin(df, "Major","Admission", relative_freq = True, show_values = True)

# %% [markdown]
# El departamento de Physics and Astronomy el que más admisiones ha tenido.
# El de Psychology el que menos.

# %% [markdown]
# ### Ejercicio 3
#
# Repite el análisis para "Admission" y "Gender" y responde a las siguientes preguntas:
# * ¿Existe una diferencia visual significativa entre el porcentaje de admitidos de cada género?
# * ¿Cuál de los dos grupos tiene más admisiones?

# %%
pinta_distribucion_categoricas(df,["Admission","Gender"], relativa= True, mostrar_valores= True)

# %%
plot_categorical_relationship_fin(df, "Admission","Gender", show_values= True)

# %%
plot_categorical_relationship_fin(df, "Gender","Admission", relative_freq = True, show_values = True)

# %% [markdown]
# El grupo masculino tiene más admisiones que el femenido, pero no hay una diferencia enorme, solo del 9%.

# %% [markdown]
# ### Ejercicio 4
#
# Carga el dataset de propinas (tips) que conoces de la unidad anterior y que se encuentra en la ruta "./data/tips.csv", deshazte de las columnas innecesarias

# %%
df = pd.read_csv("/Users/alvarosanchez/ONLINE_DS_THEBRIDGE_ALVAROSMMS-1/ONLINE_DS_THEBRIDGE_ALVAROSMMS/Sprint_7/Unidad_2/Ejercicios_Workout/data/tips.csv")

df.head()
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3
# 3           3       23.68  3.31    Male     No  Sun  Dinner     2
# 4           4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Ejercicio 5
#
# Haz el análisis bivariante de "tip" y "sex" (emplea las funciones del workout importándolas del módulo `bootcampviztools`, o utiliza las visualizaciones del notebook en el repositorio), añade el cálculo de la media y mediana de la variable continua por cada valor de la variable categórica, y contesta a las siguientes preguntas:
# * ¿Existe alguna diferencia visualmente significativa entre las propinas de los grupos de la variable "sex"?
# * ¿Son diferentes respecto al  conjunto total?

# %%
plot_categorical_numerical_relationship(df,"sex","tip", measure = "median")

# %%
plot_categorical_numerical_relationship(df,"sex","tip")

# %%
df["tip"].mean()
# Out:
# np.float64(2.99827868852459)

# %% [markdown]
# Diferencias visuales: Las propinas de los hombres tienen una media ligeramente superior (3.09) en comparación con las mujeres (2.83). La mediana también refleja una diferencia similar (hombres 3.00 frente a mujeres 2.75).
#
# Comparación con el conjunto total:
#
# La media general de propinas es 2.998, estando las mujeres por debajo de esta y los hombres apenas por encima.
# La mediana general es 2.9, y las diferencias entre géneros son coherentes con esta tendencia.

# %% [markdown]
# ### Ejercicio 6
#
# Repite el análisis pero esta vez para "tip" y "smoker", añade también el cálculo de la media y de la mediana de la variable continua por cada valor de la variable categórica, y contesta a las siguiente pregunta:
# * ¿Existe alguna diferencia visualmente significativa entre las propinas de los grupos de la variable "smoker"?

# %%
plot_categorical_numerical_relationship(df,"smoker","tip", measure = "median")

# %%
plot_categorical_numerical_relationship(df,"smoker","tip")

# %% [markdown]
# No hay una diferencia visualmente significativa en las propinas entre fumadores y no fumadores. Las medias son muy similares, con los fumadores apenas por encima. Sin embargo, la mediana sugiere que los fumadores tienen una ligera tendencia a dar propinas más altas.

# %% [markdown]
# ### Ejericicio 7
#
# Carga ahora el datase de accidentes de coches, que se encuentra en la ruta "./data/car_crashes.csv" y deshazte de las columnas innecesarias

# %%
df= pd.read_csv("/Users/alvarosanchez/ONLINE_DS_THEBRIDGE_ALVAROSMMS-1/ONLINE_DS_THEBRIDGE_ALVAROSMMS/Sprint_7/Unidad_2/Ejercicios_Workout/data/car_crashes.csv",delimiter="|")
df.set_index(df.columns[0],inplace=True)

df.head()
# Out:
#             total  speeding  alcohol  not_distracted  no_previous  \
# Unnamed: 0
# 0            18.8     7.332    5.640          18.048       15.040
# 1            18.1     7.421    4.525          16.290       17.014
# 2            18.6     6.510    5.208          15.624       17.856
# 3            22.4     4.032    5.824          21.056       21.280
# 4            12.0     4.200    3.360          10.920       10.680
#
#             ins_premium  ins_losses abbrev
# Unnamed: 0
# 0                784.55      145.08     AL
# 1               1053.48      133.93     AK
# 2                899.47      110.35     AZ
# 3                827.34      142.39     AR
# 4                878.41      165.63     CA

# %% [markdown]
# ### Ejercicio 8
#
# Haz un analisis bivairante entre "total" y "speeding". Muestra su diagrama de dispersión y su valor de correlación de pearson obtenido con pandas. Luego contesta a la siguiente pregunta
# * ¿Existe alguna relación visual entre las variables?¿Y numérica?

# %%
grafico_dispersion_con_correlacion(df,"total","speeding", 20)

# %%
from scipy.stats import pearsonr

pearsonr(df["total"], df["speeding"], alternative= "less")
# Out:
# PearsonRResult(statistic=np.float64(0.6115476008001185), pvalue=np.float64(0.9999990664804446))

# %% [markdown]
# Se ve claramente que al tener un cofeficiente de Pearson muy cerca a 1, las dos variable incrementan linealmente.
# Es decir a mayor velocidad, mayor es el múmero de accidentes.

# %% [markdown]
# ### Ejercicio 9
#
# Usa scipy tal como lo hicimos en el workout para hacer el test de correlación. ¿Cuál es el p-value?¿Qué podemos decir de la correlación lineal entre "total" y "speeding"?

# %% [markdown]
# Contestado arriba
