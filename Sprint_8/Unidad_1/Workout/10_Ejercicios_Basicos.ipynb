# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Para ejercitarte y afianzar lo aprendido sobre conceptos básicos de Matplotlib, completa los siguientes ejercicios. Recuerda que necesitarás datos que están en el directorio data que acompaña al notebook (búscalo en el repositorio de ejercicios)
#
# La solución a los mismos las tienes ya, intenta no mirarlos de primeras pero no dejes de hacerlo cuando hayas terminado por si te pudieran aportar.

# %% [markdown]
# ### Ejercicio 0

# %% [markdown]
# Importa los paquetes y módulos que necesites a lo largo del notebook

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8-white")

import numpy as np

# %% [markdown]
# ### Ejercicio 1
#
# Construye la siguiente figura con dos subplots utilizando el estilo MATLAB (es decir plt.\<funcion\>, no usando objetos `Axes`)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = np.linspace(0,10,100)
plt.plot(x,np.sin(x), label="Seno")
plt.title("Seno")
# Out:
# Text(0.5, 1.0, 'Seno')

# %%
x = np.linspace(0,10,100)
y_sin = np.sin(x)
y_cos = np.cos(x)

plt.subplot(1,2,1)
plt.plot(x,y_sin)
plt.title("Seno")

plt.subplot(1,2,2)
plt.plot(x,y_cos)
plt.title("Coseno")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Ejercicio 2
#
# Reproduce la imagen de la figura usando tres subplots en una columna, utilizando objetos `Axes`. Las dos primeras son las funciones anteriores y la tercera es la tangente (np.tan)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = np.linspace(0,10,100)
y_sin = np.sin(x)
y_cos = np.cos(x)
y_tan = np.tan(x)

fig,axs = plt.subplots(3,1,figsize= (6,8))

axs[0].plot(x,y_sin,color="red")
axs[0].set_title("Seno")

axs[1].plot(x,y_cos,color="green")
axs[1].set_title("Coseno")

axs[2].plot(x,y_tan,color="blue")
axs[2].set_title("Tangente")

axs[2].set_ylim(-40,40)

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Ejercicio 3: Ajuste de Colores y Estilos de Línea
#
# Modifica la primera figura para que se muestre de la siguiente manera

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = np.linspace(0,10,100)
y_sin = np.sin(x)
y_cos = np.cos(x)

plt.subplot(1,2,1)
plt.plot(x,y_sin,"--m")
plt.title("Seno")

plt.subplot(1,2,2)
plt.plot(x,y_cos,"--c")
plt.title("Coseno")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Ejercicio 4
#
# Reproduce la figura siguiente. Recuerda que las funciones seno hiperbólico y coseno hiperbólico se obtienen así:
# * np.sinh, seno hiperbólico;
# * np.cosh, coseno hiperbólico;

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = np.linspace(0,10,100)
y_sin = np.sinh(x)
y_cos = np.cosh(x)

fig,axs = plt.subplots(2,1,figsize= (6,8))

axs[0].plot(x,y_sin,color="red")
axs[0].set_title("Seno Hiperbólico")
axs[0].set_xlabel("x")
axs[0].set_ylabel("sinh(x)")

axs[1].plot(x,y_cos,color="blue")
axs[1].set_title("Coseno Hiperbólico")
axs[1].set_xlabel("y")
axs[1].set_ylabel("cosh(x)")

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Ejercicio 5: Ajustando el Espaciado de Subplots
#
# Reproduce la siguiente figura con cuatro subplots, ajusta el espaciado entre los subplots para evitar la superosición (tal y como ves en la figura), emplea `subplots_adjust` y los parámetros hspace y wspace.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = np.linspace(0,10,100)
y_sin = np.sinh(x)
y_cos = np.cosh(x)
y_tan = np.tan(x)
y_log = np.log(x)

fig,axs = plt.subplots(2,2,figsize= (6,8))

axs[0][0].plot(x,y_sin)

axs[0][1].plot(x,y_cos)

axs[1][0].plot(x,y_tan)

axs[1][1].plot(x,y_log)


plt.tight_layout()
#plt.subplots_adjust(hspace=0.5,wspace=0.5) hacen lo mismo, solo que esta lo ajusta a lo que quieras
plt.show()
# Out:
# /var/folders/pp/htctz74j4zx_4s8mzg9b8h6m0000gn/T/ipykernel_1584/2848598304.py:5: RuntimeWarning: divide by zero encountered in log
#   y_log = np.log(x)

# %% [markdown]
# ### Ejercicio 6:
#
# Reproduce la figura siguiente empleando sólo el estilo MATLAB (plt.\<funcion>\) y creando solo el contenido de los dos primeros gráficos (fila 1). Luego usa el estilo con métodos (objetos `axes`) para añadir el tercer gráfico.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = np.linspace(0,10,100)
y_cos = np.cosh(x)
y_sqr = np.sqrt(x)
y_sin = np.sin(x)

fig, axs = plt.subplots(2,1,figsize=(6,8))

plt.subplot(2,1,1)
plt.plot(x,y_cos,label="coseno", color="blue")
plt.plot(x,y_sqr,label="raíz cuadrada", color="orange")
plt.title("Raíz cuadrada y Coseno")
plt.legend()

axs[1].plot(x,y_sin,color="blue")
axs[1].set_title("Seno")

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Ejercicio 7
#
# Para terminar, reproduce la imagen de la figura

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = np.linspace(0,10,100)
y=np.sin(x)

plt.figure(figsize=(6,4))

plt.plot(x,y,marker="o",color="blue", markerfacecolor="yellow",markeredgecolor="blue")

plt.title("Ejemplo de Marcadores")
plt.legend()

plt.show()
# Out:
# /var/folders/pp/htctz74j4zx_4s8mzg9b8h6m0000gn/T/ipykernel_1584/1503560741.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
